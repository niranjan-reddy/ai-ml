# %%
# Import Libraries
from nltk.corpus import stopwords
set(stopwords.words('english'))
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

import matplotlib.pyplot as plt

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import sklearn as sk
import math
import itertools

# %%
# Folder Path - Derive the path using system properties:
        #cwd = os.getcwd()
        #print("Current Working Directory: ", cwd)
        #path = ''
        #path = os.getcwd() + '\stories'
        #print("PATH: ", path)
        
# Change the directory to 'stories'
path = r'C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories'
os.chdir(path)

# Read text File and Print
def print_text_file_content(file_path):
    with open(file_path, 'r') as f:
        print(f.read())
        
# Read text File and Return
def read_text_file_content(file_path):
    with open(file_path, 'r') as f:
        return f.read()

# %%
# Array of Stories
stories_whole = []
stories = []
filenames = []
filepaths = []
dataset = []

alpha = 0.3

# %%
# iterate through all files
for file in os.listdir():
    # Check whether file is in text format or not. However we have multiple extensions for our story files, hence the file extension check is not necessary.
    #if file.endswith(".txt"):
    
    file_path = f"{path}\{file}"
    #print('File: ', file_path)

    # Print Text File Content
    # print_text_file_content(file_path)

    # Get Text File Name and Content to 2D Array
    col = []
    col.append(file)
    col.append(read_text_file_content(file_path))
    stories_whole.append(col)
    stories.append(read_text_file_content(file_path))
    filenames.append(file)
    filepaths.append(file_path)
    dataset.append((file_path, file, read_text_file_content(file_path)))
        
print('# of Stories: ', len(stories))
# Out:
# # of Stories:  12

# %%
import pandas as pd
df = pd.DataFrame({'filepath': filepaths, 'filename': filenames, 'story': stories})
#print(df)
df.head()

print(len(dataset))
# Out:
# 12

# %%
def print_doc(id):
    print(dataset[id])
    file = open(dataset[id][0], 'r', encoding='cp1250')
    text = file.read().strip()
    file.close()
    print(text)

# %%
N = len (dataset)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### 1) Remove Stopwords

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %% [markdown]
# ### 2) Remove the Punctuations, Special Characters, Convert text to Lower Case

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    data = stemming(data)
    data = remove_punctuation(data)
    data = convert_numbers(data)
    data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %% [markdown]
# ## Data Extraction

# %%
# Run at least once the following scripts to download STOPWORDS and PUNKT. Subsequent downloads are not necessary.
#nltk.download('stopwords')
#nltk.download('punkt')

processed_text = []

for i in dataset[:N]:
    file = open(i[0], 'r', encoding="utf8", errors='ignore')
    text = file.read().strip()
    file.close()

    processed_text.append(word_tokenize(str(preprocess(text))))

# %% [markdown]
# ## Calculating DF for all words

# %%
DF = {}

for i in range(N):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}
            DF[w] = {i}
        
for i in DF:
    DF[i] = len(DF[i])

# %%
DF
# Out:
# {'children': 3,
#  'sli': 2,
#  'fox': 1,
#  'mr': 5,
#  'rabbit': 2,
#  'sat': 8,
#  'front': 4,
#  'porch': 1,
#  'rock': 3,
#  'eat': 5,
#  'great': 8,
#  'big': 7,
#  'carrot': 1,
#  'look': 9,
#  'like': 11,
#  'come': 11,
#  'road': 4,
#  'said': 10,
#  'walk': 9,
#  'end': 8,
#  'shade': 2,
#  'eye': 9,
#  'paw': 1,
#  'exclaim': 5,
#  'good': 9,
#  'morn': 8,
#  'cri': 7,
#  'across': 7,
#  'yard': 5,
#  'repli': 6,
#  'slight': 4,
#  'frown': 1,
#  'face': 9,
#  'well': 11,
#  'havent': 3,
#  'seen': 8,
#  'long': 9,
#  'time': 11,
#  'thought': 9,
#  'would': 9,
#  'stop': 7,
#  'chat': 2,
#  'could': 11,
#  'rude': 2,
#  'home': 8,
#  'even': 9,
#  'enemi': 3,
#  'offer': 7,
#  'seat': 3,
#  'take': 8,
#  'chair': 5,
#  'polit': 3,
#  'stay': 8,
#  'leav': 8,
#  'ask': 8,
#  'mother': 3,
#  'dinner': 2,
#  'tonight': 2,
#  'wont': 7,
#  'three': 10,
#  'littl': 10,
#  'rab': 1,
#  'oh': 5,
#  'know': 7,
#  'want': 10,
#  'us': 10,
#  'pretend': 3,
#  'disappoint': 2,
#  'sorri': 5,
#  'engag': 5,
#  'today': 4,
#  'tomorrow': 2,
#  'chuckl': 5,
#  'inwardli': 1,
#  'readili': 2,
#  'agr': 5,
#  'next': 6,
#  'day': 10,
#  'wish': 8,
#  'trot': 1,
#  'toward': 7,
#  'soon': 8,
#  'sight': 6,
#  'ran': 9,
#  'hou': 8,
#  'call': 10,
#  'get': 9,
#  'thing': 10,
#  'togeth': 9,
#  'put': 9,
#  'rubber': 2,
#  'boot': 2,
#  'move': 4,
#  'quickli': 6,
#  'piney': 1,
#  'wood': 5,
#  'brook': 1,
#  'old': 8,
#  'found': 9,
#  'destroy': 3,
#  'famili': 4,
#  'delight': 3,
#  'new': 6,
#  'woodland': 1,
#  'tower': 1,
#  'pine': 2,
#  'ground': 7,
#  'cover': 7,
#  'needl': 1,
#  'made': 10,
#  'soft': 5,
#  'carpet': 5,
#  'wind': 9,
#  'music': 1,
#  'tree': 5,
#  'bird': 3,
#  'sang': 1,
#  'fragranc': 2,
#  'flower': 3,
#  'fill': 5,
#  'air': 7,
#  'huge': 5,
#  'hollow': 4,
#  'burrow': 1,
#  'deep': 5,
#  'cozi': 1,
#  'squirrel': 1,
#  'left': 9,
#  'nut': 1,
#  'hidden': 1,
#  'around': 4,
#  'owl': 1,
#  'hoot': 1,
#  'throughout': 1,
#  'night': 8,
#  'cricket': 2,
#  'chirp': 1,
#  'merrili': 1,
#  'knock': 4,
#  'door': 9,
#  'hedgehog': 1,
#  'answer': 8,
#  'inquir': 3,
#  'wick': 4,
#  'grin': 4,
#  'cun': 3,
#  'eedgehog': 1,
#  'none': 6,
#  'cordial': 1,
#  'part': 9,
#  'unknown': 5,
#  'right': 8,
#  'yesterday': 4,
#  'ah': 5,
#  'go': 12,
#  'plan': 4,
#  'real': 6,
#  'feast': 2,
#  'dont': 8,
#  'enjoy': 4,
#  'smack': 3,
#  'lip': 5,
#  'think': 8,
#  'goodi': 1,
#  'much': 9,
#  'let': 9,
#  'nice': 3,
#  'young': 8,
#  'grasshopp': 1,
#  'softli': 2,
#  'noth': 9,
#  'tender': 1,
#  'fairli': 1,
#  'dribbl': 1,
#  'mouth': 8,
#  'dainti': 2,
#  'pass': 9,
#  'field': 3,
#  'number': 5,
#  'sack': 3,
#  'open': 9,
#  'rake': 1,
#  'bake': 1,
#  'appl': 2,
#  'deilici': 1,
#  'greedi': 1,
#  'resist': 1,
#  'went': 8,
#  'grab': 5,
#  'threw': 6,
#  'shoulder': 8,
#  'way': 12,
#  'becam': 8,
#  'suspici': 2,
#  'reach': 10,
#  'silli': 2,
#  'dumpl': 1,
#  'everi': 7,
#  'hair': 6,
#  'head': 11,
#  'stood': 7,
#  'fright': 1,
#  'foolish': 4,
#  'greed': 1,
#  'trap': 1,
#  'straighten': 2,
#  'cook': 3,
#  'eaten': 1,
#  'never': 9,
#  'pay': 6,
#  'tire': 3,
#  'rain': 6,
#  'begun': 4,
#  'fall': 5,
#  'dri': 5,
#  'place': 10,
#  'sit': 8,
#  'throw': 5,
#  'drop': 8,
#  'heavili': 3,
#  'upon': 10,
#  'wow': 1,
#  'jump': 5,
#  'shot': 2,
#  'sharp': 6,
#  'quill': 1,
#  'might': 8,
#  'fro': 1,
#  'tri': 9,
#  'pull': 3,
#  'gone': 5,
#  'scream': 5,
#  'log': 3,
#  'began': 10,
#  'neighbor': 1,
#  'bring': 8,
#  'honey': 1,
#  'crawl': 2,
#  'bag': 5,
#  'slowli': 2,
#  'allow': 4,
#  'fool': 3,
#  'one': 12,
#  'el': 7,
#  'meanwhil': 4,
#  'live': 11,
#  'happili': 4,
#  'play': 6,
#  'crystal': 2,
#  'clear': 5,
#  'wade': 1,
#  'sail': 3,
#  'leaf': 3,
#  'boat': 3,
#  'catch': 5,
#  'silveri': 1,
#  'minnow': 1,
#  'dart': 2,
#  'late': 6,
#  'papa': 1,
#  'mama': 1,
#  'fire': 7,
#  'talk': 6,
#  'robe': 2,
#  'bedroom': 4,
#  'slipper': 1,
#  'read': 6,
#  'newspap': 3,
#  'spectacl': 1,
#  'lovingli': 1,
#  'dress': 6,
#  'housecoat': 1,
#  'red': 6,
#  'knit': 1,
#  'sock': 1,
#  'sniff': 1,
#  'came': 9,
#  'suddenli': 8,
#  'ear': 4,
#  'whisper': 3,
#  'full': 7,
#  'concern': 4,
#  'alarm': 7,
#  'ye': 8,
#  'voic': 7,
#  'trembl': 3,
#  'straw': 2,
#  'tell': 7,
#  'quiet': 4,
#  'instruct': 3,
#  'caution': 3,
#  'mice': 1,
#  'sinc': 6,
#  'behav': 2,
#  'obedi': 1,
#  'told': 8,
#  'stick': 4,
#  'besid': 7,
#  'oak': 4,
#  'breath': 5,
#  'shall': 9,
#  'scratch': 3,
#  'earth': 7,
#  'dig': 2,
#  'furiou': 6,
#  'poor': 9,
#  'still': 8,
#  'frighten': 3,
#  'heart': 6,
#  'thump': 2,
#  'shake': 6,
#  'bulg': 1,
#  'panic': 1,
#  'distanc': 4,
#  'heard': 7,
#  'toot': 1,
#  'horn': 2,
#  'woof': 1,
#  'bark': 2,
#  'dog': 2,
#  'hunter': 3,
#  'gave': 6,
#  'bound': 4,
#  'relief': 1,
#  'nearer': 2,
#  'bay': 2,
#  'hound': 2,
#  'busili': 2,
#  'fail': 3,
#  'hear': 7,
#  'first': 8,
#  'back': 9,
#  'listen': 7,
#  'away': 10,
#  'start': 7,
#  'run': 7,
#  'loudli': 2,
#  'hor': 4,
#  'feet': 6,
#  'beat': 4,
#  'excit': 3,
#  'rhythm': 1,
#  'coat': 3,
#  'urg': 4,
#  'chase': 3,
#  'hill': 5,
#  'meadow': 1,
#  'life': 7,
#  'closer': 2,
#  'spi': 1,
#  'hole': 7,
#  'among': 5,
#  'bush': 1,
#  'slid': 1,
#  'side': 7,
#  'stream': 5,
#  'water': 6,
#  'lost': 7,
#  'scent': 2,
#  'took': 10,
#  'opposit': 4,
#  'direct': 8,
#  'near': 5,
#  'death': 7,
#  'resolv': 2,
#  'bother': 2,
#  'turn': 7,
#  'safe': 6,
#  'last': 9,
#  'prayer': 1,
#  'thanksgiv': 1,
#  'prai': 5,
#  'father': 4,
#  'art': 4,
#  'heaven': 5,
#  'hustl': 1,
#  'make': 7,
#  'mint': 1,
#  'tea': 3,
#  'hot': 7,
#  'chocol': 1,
#  'pile': 3,
#  'high': 6,
#  'whip': 2,
#  'cream': 1,
#  'beulah': 1,
#  'murrel': 1,
#  'dreamland': 4,
#  'hundr': 6,
#  'thirteen': 4,
#  'five': 5,
#  'fifti': 5,
#  'eight': 4,
#  'thousand': 7,
#  'twenti': 6,
#  'four': 6,
#  'fourteen': 4,
#  'seventeen': 4,
#  'bb': 4,
#  'text': 4,
#  'file': 5,
#  'junki': 4,
#  'rpgnet': 4,
#  'gm': 4,
#  'archiv': 4,
#  'site': 4,
#  'adveniur': 1,
#  'gabl': 1,
#  'adventur': 6,
#  'sherlock': 4,
#  'holm': 4,
#  'quit': 7,
#  'abruptli': 1,
#  'dramat': 2,
#  'associ': 2,
#  'idea': 6,
#  'channel': 2,
#  'activ': 2,
#  'chatti': 1,
#  'mood': 1,
#  'howev': 8,
#  'settl': 3,
#  'worn': 5,
#  'low': 2,
#  'armchair': 2,
#  'curl': 3,
#  'pipe': 3,
#  'visitor': 4,
#  'arriv': 7,
#  'mad': 4,
#  'bull': 3,
#  'give': 8,
#  'clearer': 1,
#  'impress': 3,
#  'occur': 4,
#  'flown': 1,
#  'negro': 2,
#  'burst': 4,
#  'room': 5,
#  'comic': 1,
#  'figur': 3,
#  'terrif': 1,
#  'loud': 2,
#  'gray': 2,
#  'check': 2,
#  'suit': 3,
#  'flow': 4,
#  'salmon': 1,
#  'colour': 4,
#  'tie': 3,
#  'broad': 3,
#  'flatten': 1,
#  'nose': 4,
#  'thrust': 5,
#  'forward': 3,
#  'sullen': 2,
#  'dark': 6,
#  'smoulder': 1,
#  'gleam': 2,
#  'malic': 1,
#  'genlmen': 1,
#  'masser': 1,
#  'rai': 4,
#  'languid': 1,
#  'smile': 4,
#  'un': 1,
#  'pleasant': 4,
#  'stealthi': 1,
#  'step': 5,
#  'round': 9,
#  'angl': 2,
#  'tabl': 6,
#  'see': 11,
#  'keep': 5,
#  'hand': 9,
#  'folk': 4,
#  'busi': 5,
#  'ness': 1,
#  'manag': 5,
#  'affair': 3,
#  'got': 6,
#  'fine': 7,
#  'growl': 2,
#  'savag': 2,
#  'damn': 1,
#  'trim': 1,
#  'bit': 6,
#  'ive': 3,
#  'handl': 2,
#  'kind': 6,
#  'didnt': 5,
#  'swung': 3,
#  'knot': 3,
#  'lump': 2,
#  'fist': 3,
#  'friend': 9,
#  'examin': 4,
#  'close': 6,
#  'interest': 5,
#  'born': 3,
#  'degr': 2,
#  'may': 5,
#  'ici': 1,
#  'cool': 2,
#  'clatter': 2,
#  'pick': 5,
#  'poker': 2,
#  'case': 5,
#  'manner': 4,
#  'less': 5,
#  'flamboy': 1,
#  'given': 5,
#  'fair': 4,
#  'warnin': 1,
#  'harrow': 1,
#  'im': 7,
#  'mean': 5,
#  'intend': 4,
#  'buttin': 1,
#  'aint': 1,
#  'law': 3,
#  'either': 4,
#  'ill': 8,
#  'also': 5,
#  'forget': 6,
#  'meet': 6,
#  'smell': 2,
#  'arent': 1,
#  'steve': 1,
#  'dixi': 1,
#  'bruiser': 1,
#  'name': 6,
#  'youll': 4,
#  'sure': 8,
#  'certainli': 6,
#  'need': 8,
#  'stare': 4,
#  'hideou': 3,
#  'kill': 3,
#  'perkin': 1,
#  'outsid': 7,
#  'holborn': 1,
#  'bar': 3,
#  'sprung': 1,
#  'leaden': 1,
#  'ere': 2,
#  'trainin': 1,
#  'ring': 5,
#  'birmingham': 1,
#  'boy': 4,
#  'done': 6,
#  'troubl': 6,
#  'magistr': 1,
#  'watch': 8,
#  'barney': 1,
#  'stockdal': 1,
#  'help': 7,
#  'lord': 1,
#  'enough': 6,
#  'mornin': 1,
#  'hope': 6,
#  'hard': 7,
#  'feelin': 1,
#  'visit': 7,
#  'unless': 3,
#  'sent': 6,
#  'secret': 4,
#  'genlman': 1,
#  'mention': 5,
#  'set': 10,
#  'selp': 1,
#  'say': 8,
#  'whole': 6,
#  'truth': 4,
#  'without': 7,
#  'wait': 6,
#  'question': 5,
#  'bolt': 2,
#  'almost': 5,
#  'precipit': 1,
#  'enter': 6,
#  'ash': 2,
#  'glad': 5,
#  'forc': 7,
#  'break': 5,
#  'woolli': 1,
#  'watson': 4,
#  'observ': 5,
#  'manoeuvr': 1,
#  'realli': 8,
#  'rather': 6,
#  'harmless': 1,
#  'fellow': 5,
#  'muscular': 1,
#  'blu': 1,
#  'tere': 2,
#  'babi': 1,
#  'easili': 6,
#  'cow': 1,
#  'spencer': 1,
#  'john': 2,
#  'gang': 3,
#  'taken': 6,
#  'dirti': 1,
#  'work': 8,
#  'immedi': 3,
#  'princip': 3,
#  'astut': 1,
#  'person': 5,
#  'special': 2,
#  'assault': 2,
#  'intimid': 1,
#  'panicular': 1,
#  'occa': 3,
#  'weald': 1,
#  'decid': 4,
#  'matter': 6,
#  'worth': 3,
#  'anyon': 6,
#  'must': 8,
#  'someth': 6,
#  'interlud': 1,
#  'maberley': 1,
#  'note': 4,
#  'care': 8,
#  'wire': 2,
#  'dear': 4,
#  'success': 3,
#  'strang': 7,
#  'incid': 4,
#  'connect': 3,
#  'valu': 4,
#  'advic': 4,
#  'find': 7,
#  'morrow': 4,
#  'within': 6,
#  'short': 3,
#  'station': 4,
#  'believ': 6,
#  'husband': 2,
#  'mortim': 1,
#  'earli': 4,
#  'client': 3,
#  'faith': 2,
#  'mari': 2,
#  'address': 3,
#  'spare': 3,
#  'railway': 1,
#  'journey': 5,
#  'shorter': 1,
#  'drive': 5,
#  'brought': 5,
#  'brick': 2,
#  'timber': 1,
#  'villa': 2,
#  'stand': 7,
#  'acr': 1,
#  'undevelop': 1,
#  'grassland': 1,
#  'small': 6,
#  'project': 3,
#  'upper': 1,
#  'window': 6,
#  'feebl': 2,
#  'attempt': 3,
#  'justifi': 1,
#  'behind': 5,
#  'grove': 3,
#  'melancholi': 2,
#  'half': 6,
#  'grown': 3,
#  'aspect': 1,
#  'depress': 3,
#  'furnish': 4,
#  'ladi': 3,
#  'receiv': 6,
#  'elderli': 2,
#  'bore': 3,
#  'mark': 5,
#  'refin': 2,
#  'ment': 3,
#  'cultur': 1,
#  'rememb': 6,
#  'madam': 2,
#  'though': 8,
#  'year': 7,
#  'use': 6,
#  'servic': 1,
#  'trifl': 2,
#  'probabl': 5,
#  'familiar': 1,
#  'son': 4,
#  'dougla': 1,
#  'knew': 8,
#  'slightli': 2,
#  'cour': 6,
#  'london': 3,
#  'magnif': 1,
#  'creatur': 3,
#  'dead': 8,
#  'attach': 3,
#  'rome': 1,
#  'die': 4,
#  'pneumonia': 1,
#  'month': 5,
#  'man': 8,
#  'known': 5,
#  'vital': 2,
#  'aliv': 4,
#  'inten': 1,
#  'fibr': 1,
#  'ruin': 4,
#  'debonair': 1,
#  'splendid': 3,
#  'moodi': 1,
#  'moro': 1,
#  'brood': 1,
#  'devel': 1,
#  'ope': 1,
#  'broken': 4,
#  'singl': 4,
#  'seem': 6,
#  'gallant': 1,
#  'cynic': 1,
#  'love': 5,
#  'woman': 6,
#  'fiend': 1,
#  'lad': 2,
#  'dr': 2,
#  'happen': 4,
#  'lead': 4,
#  'retir': 3,
#  'neighbour': 2,
#  'ago': 4,
#  'agent': 1,
#  'exactli': 3,
#  'money': 7,
#  'object': 4,
#  'sever': 6,
#  'empti': 7,
#  'market': 2,
#  'appear': 7,
#  'equal': 2,
#  'elig': 1,
#  'natur': 7,
#  'therefor': 3,
#  'price': 3,
#  'pound': 4,
#  'ad': 1,
#  'desir': 5,
#  'buy': 2,
#  'furnitur': 3,
#  'sum': 3,
#  'alway': 7,
#  'travel': 5,
#  'bargain': 1,
#  'mistress': 1,
#  'rest': 8,
#  'agreement': 1,
#  'drawn': 4,
#  'luckili': 4,
#  'show': 5,
#  'sutro': 1,
#  'lawyer': 2,
#  'document': 2,
#  'awar': 2,
#  'sign': 5,
#  'legal': 1,
#  'anyth': 5,
#  'privat': 3,
#  'possess': 5,
#  'point': 7,
#  'meant': 2,
#  'sell': 3,
#  'everyth': 5,
#  'cloth': 5,
#  'jewel': 4,
#  'concess': 1,
#  'per': 1,
#  'sonal': 1,
#  'effect': 4,
#  'uncheck': 1,
#  'liber': 1,
#  'fad': 1,
#  'unusu': 3,
#  'extraordinari': 5,
#  'interrupt': 1,
#  'silenc': 4,
#  'strode': 1,
#  'flung': 1,
#  'drag': 3,
#  'gaunt': 1,
#  'seiz': 4,
#  'ungainli': 1,
#  'struggl': 2,
#  'awkward': 3,
#  'chicken': 1,
#  'torn': 2,
#  'squawk': 1,
#  'coop': 2,
#  'alon': 5,
#  'doin': 1,
#  'screech': 1,
#  'susan': 1,
#  'maam': 1,
#  'comin': 1,
#  'stayin': 1,
#  'lunch': 2,
#  'minut': 6,
#  'narr': 3,
#  'wheezi': 1,
#  'sulki': 1,
#  'amaz': 5,
#  'captor': 1,
#  'anyhow': 3,
#  'pullin': 1,
#  'mere': 3,
#  'presenc': 4,
#  'write': 4,
#  'consult': 2,
#  'post': 4,
#  'letter': 4,
#  'wrote': 4,
#  'messag': 5,
#  'lie': 6,
#  'peopl': 4,
#  'fib': 1,
#  'bad': 3,
#  'treach': 1,
#  'erou': 1,
#  'saw': 7,
#  'speak': 5,
#  'someon': 6,
#  'hedg': 1,
#  'sullenli': 1,
#  'suppo': 4,
#  'spoke': 3,
#  'ten': 4,
#  'lay': 5,
#  'world': 7,
#  'rich': 5,
#  'far': 8,
#  'earn': 3,
#  'tenner': 1,
#  'hell': 2,
#  'languag': 2,
#  'send': 5,
#  'box': 3,
#  'flounc': 1,
#  'bye': 3,
#  'paregor': 1,
#  'stuff': 2,
#  'continu': 7,
#  'flush': 4,
#  'angri': 3,
#  'game': 4,
#  'postmark': 2,
#  'yet': 6,
#  'word': 9,
#  'employ': 3,
#  'inclin': 2,
#  'latter': 2,
#  'blunder': 1,
#  'form': 5,
#  'black': 6,
#  'warn': 6,
#  'eleven': 2,
#  'oclock': 4,
#  'quick': 5,
#  'sea': 3,
#  'captain': 3,
#  'ferguson': 1,
#  'remark': 4,
#  'ever': 8,
#  'wonder': 7,
#  'whether': 5,
#  'buri': 3,
#  'treasur': 4,
#  'nowaday': 1,
#  'offic': 2,
#  'bank': 3,
#  'lunat': 2,
#  'dull': 1,
#  'valuabl': 4,
#  'raphael': 1,
#  'folio': 1,
#  'shakespear': 1,
#  'rarer': 1,
#  'crown': 2,
#  'derbi': 1,
#  'hardli': 5,
#  'mysteri': 5,
#  'openli': 2,
#  'state': 4,
#  'covet': 1,
#  'lock': 6,
#  'stock': 3,
#  'barrel': 2,
#  'pure': 1,
#  'mental': 3,
#  'analysi': 2,
#  'finer': 1,
#  'nearli': 5,
#  'two': 8,
#  'better': 5,
#  'period': 2,
#  'urgent': 1,
#  'demand': 3,
#  'gather': 5,
#  'whatev': 3,
#  'bought': 3,
#  'ind': 5,
#  'best': 7,
#  'develop': 2,
#  'data': 1,
#  'capabl': 3,
#  'anoth': 6,
#  'maid': 4,
#  'bang': 2,
#  'girl': 2,
#  'spend': 4,
#  'possibl': 5,
#  'protect': 3,
#  'obscur': 1,
#  'cant': 6,
#  'approach': 5,
#  'simpli': 4,
#  'card': 4,
#  'occup': 2,
#  'hain': 1,
#  'johnson': 1,
#  'auction': 1,
#  'valuer': 1,
#  'directori': 1,
#  'honest': 4,
#  'men': 7,
#  'conceal': 3,
#  'fresh': 5,
#  'reli': 1,
#  'hall': 3,
#  'holmess': 3,
#  'miss': 4,
#  'light': 8,
#  'trunk': 3,
#  'corner': 4,
#  'label': 2,
#  'shone': 3,
#  'milano': 1,
#  'lucern': 1,
#  'itali': 1,
#  'douglass': 1,
#  'unpack': 1,
#  'week': 5,
#  'link': 4,
#  'annuiti': 1,
#  'delay': 3,
#  'longer': 5,
#  'upstair': 1,
#  'cohtain': 1,
#  'report': 3,
#  'evid': 4,
#  'surveil': 1,
#  'lane': 1,
#  'prize': 2,
#  'fighter': 2,
#  'shadow': 4,
#  'grim': 1,
#  'menac': 1,
#  'lone': 2,
#  'clap': 2,
#  'pocket': 6,
#  'lookin': 1,
#  'gun': 1,
#  'bottl': 2,
#  'funni': 2,
#  'spose': 1,
#  'job': 4,
#  'boss': 1,
#  'order': 7,
#  'bear': 3,
#  'mind': 6,
#  'roof': 4,
#  'thoroughli': 3,
#  'skin': 4,
#  'wat': 1,
#  'doubl': 3,
#  'cross': 3,
#  'lucki': 3,
#  'knowledg': 3,
#  'crowd': 4,
#  'langdal': 1,
#  'pike': 1,
#  'imagin': 3,
#  'spent': 4,
#  'human': 4,
#  'book': 4,
#  'refer': 2,
#  'social': 1,
#  'scandal': 3,
#  'wake': 1,
#  ...}

# %%
total_vocab_size = len(DF)

# %%
total_vocab_size
# Out:
# 4118

# %%
total_vocab = [x for x in DF]

# %%
print(total_vocab[:20])
# Out:
# ['children', 'sli', 'fox', 'mr', 'rabbit', 'sat', 'front', 'porch', 'rock', 'eat', 'great', 'big', 'carrot', 'look', 'like', 'come', 'road', 'said', 'walk', 'end']

# %% [markdown]
# ## N-Grams

# %% [markdown]
# ### 3) Create Bigrams. List 10 most frequent bigrams

# %%
processed_text_merged = {}
words_merged = []
counter = 0
for items in processed_text:
    for word in items:
        processed_text_merged[counter] = word
        words_merged.append(word)
        #rint(word)
        counter +=1
        
print('processed_text_merged length: ',len(processed_text_merged))
print('words_merged length: ',len(words_merged))
# Out:
# processed_text_merged length:  21193
# words_merged length:  21193

# %%
words_merged[25:55]
# Out:
# ['eye',
#  'paw',
#  'exclaim',
#  'sli',
#  'fox',
#  'good',
#  'morn',
#  'mr',
#  'rabbit',
#  'cri',
#  'sli',
#  'fox',
#  'walk',
#  'across',
#  'yard',
#  'good',
#  'morn',
#  'repli',
#  'mr',
#  'rabbit',
#  'slight',
#  'frown',
#  'face',
#  'well',
#  'said',
#  'sli',
#  'fox',
#  'havent',
#  'seen',
#  'long']

# %% [markdown]
# ### 10 most-frequent Bigrams:

# %%
# Bigrams
bigram_series = (pd.Series(nltk.ngrams(words_merged, 2)).value_counts())[:10]
bigram_series
# Out:
# (mr, holm)          43
# (said, holm)        42
# (sli, fox)          26
# (sherlock, holm)    23
# (littl, pig)        22
# (sinbad, sailor)    19
# (one, day)          18
# (masser, holm)      16
# (mr, soam)          16
# (let, us)           16
# dtype: int64

# %%
bigram_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('20 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %% [markdown]
# ## 4) Implementing / Calculating TF-IDF

# %% [markdown]
# ### TF-IDF From Scratch

# %%
def doc_freq(word):
    c = 0
    try:
        c = DF[word]
    except:
        pass
    return c

# %%
# TF-IDF Function From Scratch...
def tf_idf_function(len_n, processed_text_input): #len_n = dataset length, processed_text_input
    tf_idf_result = {}
    story_index = 0
    
    for i in range(len_n):
        tokens = processed_text_input[i]
        counter = Counter(tokens)
        words_count = len(tokens)
        
        for token in np.unique(tokens):
            tf = counter[token] / words_count
            df = doc_freq(token)
            idf = np.log((len_n + 1)) / (df + 1)
            tf_idf_result[story_index, token] = tf * idf
            
        story_index += 1
    return(tf_idf_result)

# %%
tf_idf_result = tf_idf_function(N, processed_text)

# %%
tf_idf_result
# Out:
# {(0, 'across'): 0.0015872211370430301,
#  (0, 'agr'): 0.0010581474246953535,
#  (0, 'ah'): 0.0005290737123476767,
#  (0, 'air'): 0.00039680528426075753,
#  (0, 'alarm'): 0.00039680528426075753,
#  (0, 'allow'): 0.0006348884548172121,
#  (0, 'among'): 0.0010581474246953535,
#  (0, 'answer'): 0.000705431616463569,
#  (0, 'appl'): 0.002116294849390707,
#  (0, 'around'): 0.0006348884548172121,
#  (0, 'art'): 0.0006348884548172121,
#  (0, 'ask'): 0.000705431616463569,
#  (0, 'away'): 0.00028858566128055094,
#  (0, 'back'): 0.00031744422740860606,
#  (0, 'bag'): 0.0005290737123476767,
#  (0, 'bake'): 0.0031744422740860602,
#  (0, 'bark'): 0.0010581474246953535,
#  (0, 'bay'): 0.002116294849390707,
#  (0, 'beat'): 0.0006348884548172121,
#  (0, 'becam'): 0.000705431616463569,
#  (0, 'bedroom'): 0.0006348884548172121,
#  (0, 'began'): 0.0008657569838416528,
#  (0, 'begun'): 0.0006348884548172121,
#  (0, 'behav'): 0.0010581474246953535,
#  (0, 'besid'): 0.00039680528426075753,
#  (0, 'beulah'): 0.0015872211370430301,
#  (0, 'big'): 0.0007936105685215151,
#  (0, 'bird'): 0.0007936105685215151,
#  (0, 'boat'): 0.0007936105685215151,
#  (0, 'boot'): 0.0010581474246953535,
#  (0, 'bother'): 0.002116294849390707,
#  (0, 'bound'): 0.0006348884548172121,
#  (0, 'breath'): 0.0005290737123476767,
#  (0, 'bring'): 0.0003527158082317845,
#  (0, 'brook'): 0.00476166341112909,
#  (0, 'bulg'): 0.0015872211370430301,
#  (0, 'burrow'): 0.0015872211370430301,
#  (0, 'bush'): 0.0015872211370430301,
#  (0, 'busili'): 0.0010581474246953535,
#  (0, 'call'): 0.0008657569838416528,
#  (0, 'came'): 0.0006348884548172121,
#  (0, 'carpet'): 0.0005290737123476767,
#  (0, 'carrot'): 0.0015872211370430301,
#  (0, 'catch'): 0.0005290737123476767,
#  (0, 'caution'): 0.0007936105685215151,
#  (0, 'chair'): 0.0005290737123476767,
#  (0, 'chase'): 0.0015872211370430301,
#  (0, 'chat'): 0.0010581474246953535,
#  (0, 'children'): 0.0007936105685215151,
#  (0, 'chirp'): 0.0015872211370430301,
#  (0, 'chocol'): 0.0015872211370430301,
#  (1, 'life'): 0.0007910929459918381,
#  (1, 'light'): 0.000301368741330224,
#  (1, 'like'): 0.0007534218533255602,
#  (1, 'line'): 0.00015068437066511202,
#  (1, 'link'): 0.0001808212447981344,
#  (1, 'lip'): 0.00015068437066511202,
#  (1, 'listen'): 0.00033903983399650203,
#  (1, 'litter'): 0.00030136874133022403,
#  (1, 'littl'): 0.0006575317992659433,
#  (1, 'live'): 0.0003767109266627801,
#  ...}

# %%
len(tf_idf_result)
# Out:
# 8871

# %%
processed_text[0]
# Out:
# ['children',
#  'sli',
#  'fox',
#  'mr',
#  'rabbit',
#  'sat',
#  'front',
#  'porch',
#  'rock',
#  'eat',
#  'great',
#  'big',
#  'carrot',
#  'look',
#  'look',
#  'like',
#  'sli',
#  'fox',
#  'come',
#  'road',
#  'said',
#  'walk',
#  'end',
#  'porch',
#  'shade',
#  'eye',
#  'paw',
#  'exclaim',
#  'sli',
#  'fox',
#  'good',
#  'morn',
#  'mr',
#  'rabbit',
#  'cri',
#  'sli',
#  'fox',
#  'walk',
#  'across',
#  'yard',
#  'good',
#  'morn',
#  'repli',
#  'mr',
#  'rabbit',
#  'slight',
#  'frown',
#  'face',
#  'well',
#  'said',
#  'sli',
#  'fox',
#  'havent',
#  'seen',
#  'long',
#  'time',
#  'thought',
#  'would',
#  'stop',
#  'chat',
#  'mr',
#  'rabbit',
#  'could',
#  'rude',
#  'home',
#  'even',
#  'enemi',
#  'offer',
#  'sli',
#  'fox',
#  'seat',
#  'porch',
#  'take',
#  'chair',
#  'said',
#  'polit',
#  'sli',
#  'fox',
#  'stay',
#  'long',
#  'leav',
#  'ask',
#  'mr',
#  'rabbit',
#  'mother',
#  'good',
#  'dinner',
#  'tonight',
#  'wont',
#  'mr',
#  'rabbit',
#  'three',
#  'littl',
#  'rab',
#  'come',
#  'dinner',
#  'oh',
#  'thought',
#  'mr',
#  'rabbit',
#  'know',
#  'littl',
#  'rab',
#  'want',
#  'take',
#  'us',
#  'eat',
#  'us',
#  'pretend',
#  'disappoint',
#  'repli',
#  'sorri',
#  'sli',
#  'fox',
#  'engag',
#  'today',
#  'want',
#  'us',
#  'come',
#  'tomorrow',
#  'sli',
#  'fox',
#  'chuckl',
#  'inwardli',
#  'readili',
#  'agr',
#  'come',
#  'next',
#  'day',
#  'wish',
#  'mr',
#  'rabbit',
#  'good',
#  'day',
#  'trot',
#  'road',
#  'toward',
#  'home',
#  'soon',
#  'sight',
#  'mr',
#  'rabbit',
#  'ran',
#  'hou',
#  'call',
#  'mr',
#  'rabbit',
#  'get',
#  'thing',
#  'togeth',
#  'said',
#  'put',
#  'rubber',
#  'boot',
#  'littl',
#  'rab',
#  'move',
#  'quickli',
#  'piney',
#  'wood',
#  'across',
#  'brook',
#  'old',
#  'sli',
#  'fox',
#  'found',
#  'home',
#  'destroy',
#  'us',
#  'time',
#  'rabbit',
#  'famili',
#  'move',
#  'littl',
#  'rab',
#  'delight',
#  'new',
#  'home',
#  'woodland',
#  'tower',
#  'pine',
#  'ground',
#  'cover',
#  'pine',
#  'needl',
#  'made',
#  'soft',
#  'carpet',
#  'wind',
#  'made',
#  'music',
#  'pine',
#  'tree',
#  'bird',
#  'sang',
#  'fragranc',
#  'flower',
#  'fill',
#  'air',
#  'found',
#  'huge',
#  'hollow',
#  'tree',
#  'mr',
#  'rabbit',
#  'burrow',
#  'deep',
#  'made',
#  'cozi',
#  'home',
#  'squirrel',
#  'left',
#  'nut',
#  'hidden',
#  'around',
#  'old',
#  'tree',
#  'owl',
#  'hoot',
#  'throughout',
#  'night',
#  'cricket',
#  'chirp',
#  'merrili',
#  'next',
#  'morn',
#  'old',
#  'sli',
#  'fox',
#  'knock',
#  'door',
#  'left',
#  'mr',
#  'rabbit',
#  'mr',
#  'hedgehog',
#  'answer',
#  'door',
#  'good',
#  'morn',
#  'mr',
#  'hedgehog',
#  'mr',
#  'rabbit',
#  'inquir',
#  'sli',
#  'fox',
#  'wick',
#  'grin',
#  'cun',
#  'look',
#  'eye',
#  'repli',
#  'mr',
#  'eedgehog',
#  'none',
#  'cordial',
#  'rabbit',
#  'famili',
#  'move',
#  'part',
#  'unknown',
#  'right',
#  'left',
#  'yesterday',
#  'ah',
#  'exclaim',
#  'old',
#  'sli',
#  'fox',
#  'mr',
#  'rabbit',
#  'famili',
#  'go',
#  'dinner',
#  'mother',
#  'plan',
#  'real',
#  'feast',
#  'dont',
#  'come',
#  'enjoy',
#  'us',
#  'oh',
#  'repli',
#  'mr',
#  'hedgehog',
#  'smack',
#  'lip',
#  'think',
#  'goodi',
#  'move',
#  'much',
#  'let',
#  'go',
#  'tomorrow',
#  'like',
#  'nice',
#  'young',
#  'grasshopp',
#  'ask',
#  'sli',
#  'fox',
#  'softli',
#  'noth',
#  'good',
#  'tender',
#  'young',
#  'grasshopp',
#  'answer',
#  'mr',
#  'hedgehog',
#  'fairli',
#  'dribbl',
#  'mouth',
#  'thought',
#  'dainti',
#  'well',
#  'said',
#  'sli',
#  'fox',
#  'pass',
#  'field',
#  'number',
#  'come',
#  'get',
#  'sack',
#  'stop',
#  'field',
#  'open',
#  'sack',
#  'rake',
#  'want',
#  'mother',
#  'bake',
#  'appl',
#  'deilici',
#  'much',
#  'greedi',
#  'mr',
#  'hedgehog',
#  'resist',
#  'sack',
#  'went',
#  'sli',
#  'fox',
#  'grin',
#  'grab',
#  'sack',
#  'threw',
#  'shoulder',
#  'trot',
#  'toward',
#  'home',
#  'go',
#  'long',
#  'way',
#  'mr',
#  'hedgehog',
#  'becam',
#  'suspici',
#  'cri',
#  'long',
#  'reach',
#  'field',
#  'grasshopp',
#  'silli',
#  'greedi',
#  'hedgehog',
#  'field',
#  'grasshopp',
#  'go',
#  'eat',
#  'dinner',
#  'appl',
#  'dumpl',
#  'mother',
#  'bake',
#  'everi',
#  'hair',
#  'mr',
#  'hedgehog',
#  'head',
#  'stood',
#  'end',
#  'fright',
#  'oh',
#  'foolish',
#  'greed',
#  'trap',
#  'stay',
#  'home',
#  'straighten',
#  'hou',
#  'cook',
#  'dinner',
#  'would',
#  'sack',
#  'eaten',
#  'sli',
#  'fox',
#  'greedi',
#  'never',
#  'pay',
#  'thought',
#  'sli',
#  'fox',
#  'becam',
#  'tire',
#  'slight',
#  'rain',
#  'begun',
#  'fall',
#  'look',
#  'dri',
#  'place',
#  'sit',
#  'throw',
#  'sack',
#  'ground',
#  'chuckl',
#  'thought',
#  'sit',
#  'mr',
#  'hedgehog',
#  'drop',
#  'heavili',
#  'upon',
#  'sack',
#  'wow',
#  'wow',
#  'cri',
#  'jump',
#  'quickli',
#  'mr',
#  'hedgehog',
#  'shot',
#  'sharp',
#  'quill',
#  'might',
#  'sli',
#  'fox',
#  'ran',
#  'fro',
#  'tri',
#  'pull',
#  'quill',
#  'gone',
#  'deep',
#  'home',
#  'ran',
#  'scream',
#  'mother',
#  'old',
#  'mother',
#  'fox',
#  'threw',
#  'log',
#  'began',
#  'pull',
#  'quill',
#  'time',
#  'call',
#  'neighbor',
#  'fox',
#  'bring',
#  'honey',
#  'put',
#  'place',
#  'quill',
#  'mr',
#  'hedgehog',
#  'crawl',
#  'bag',
#  'began',
#  'walk',
#  'slowli',
#  'toward',
#  'home',
#  'thought',
#  'never',
#  'would',
#  'greedi',
#  'allow',
#  'fool',
#  'sli',
#  'fox',
#  'one',
#  'el',
#  'meanwhil',
#  'mr',
#  'rabbit',
#  'famili',
#  'live',
#  'happili',
#  'piney',
#  'wood',
#  'littl',
#  'rab',
#  'play',
#  'crystal',
#  'clear',
#  'brook',
#  'ran',
#  'wood',
#  'wade',
#  'sail',
#  'littl',
#  'leaf',
#  'boat',
#  'tri',
#  'catch',
#  'silveri',
#  'minnow',
#  'dart',
#  'late',
#  'one',
#  'even',
#  'papa',
#  'mama',
#  'rabbit',
#  'sit',
#  'cozi',
#  'fire',
#  'talk',
#  'papa',
#  'rabbit',
#  'hou',
#  'robe',
#  'bedroom',
#  'slipper',
#  'read',
#  'newspap',
#  'everi',
#  'look',
#  'spectacl',
#  'lovingli',
#  'dainti',
#  'littl',
#  'mama',
#  'rabbit',
#  'dress',
#  'flower',
#  'housecoat',
#  'red',
#  'slipper',
#  'knit',
#  'littl',
#  'sock',
#  'littl',
#  'rab',
#  'sniff',
#  'sniff',
#  'sniff',
#  'came',
#  'suddenli',
#  'ear',
#  'sli',
#  'fox',
#  'whisper',
#  'papa',
#  'rabbit',
#  'face',
#  'full',
#  'concern',
#  'alarm',
#  'ye',
#  'agr',
#  'mama',
#  'rabbit',
#  'voic',
#  'trembl',
#  'fright',
#  'go',
#  'cover',
#  'littl',
#  'rab',
#  'straw',
#  'tell',
#  'quiet',
#  'instruct',
#  'papa',
#  'rabbit',
#  'mr',
#  'rabbit',
#  'quickli',
#  'cover',
#  'littl',
#  'rab',
#  'caution',
#  'quiet',
#  'mice',
#  'sinc',
#  'well',
#  'behav',
#  'obedi',
#  'littl',
#  'rab',
#  'mother',
#  'told',
#  'left',
#  'big',
#  'stick',
#  'besid',
#  'old',
#  'oak',
#  'tree',
#  'cri',
#  'papa',
#  'rabbit',
#  'breath',
#  'shall',
#  'sniff',
#  'sniff',
#  'sniff',
#  'went',
#  'sli',
#  'fox',
#  'scratch',
#  'earth',
#  'old',
#  'hollow',
#  'tree',
#  'began',
#  'dig',
#  'furiou',
#  'poor',
#  'littl',
#  'rabbit',
#  'famili',
#  'sat',
#  'still',
#  'frighten',
#  'heart',
#  'thump',
#  'paw',
#  'shake',
#  'eye',
#  'bulg',
#  'panic',
#  'suddenli',
#  'distanc',
#  'heard',
#  'toot',
#  'toot',
#  'toot',
#  'horn',
#  'woof',
#  'woof',
#  'woof',
#  'bark',
#  'dog',
#  'papa',
#  'rabbit',
#  'whisper',
#  'fox',
#  'hunter',
#  'heart',
#  'gave',
#  'bound',
#  'relief',
#  'nearer',
#  'nearer',
#  'came',
#  'bay',
#  'hound',
#  'music',
#  'horn',
#  'old',
#  'sli',
#  'fox',
#  'busili',
#  'dig',
#  'fail',
#  'hear',
#  'first',
#  'suddenli',
#  'stop',
#  'dig',
#  'threw',
#  'back',
#  'ear',
#  'listen',
#  'quickli',
#  'jump',
#  'away',
#  'log',
#  'rabbit',
#  'famili',
#  'live',
#  'start',
#  'run',
#  'hound',
#  'right',
#  'bay',
#  'loudli',
#  'might',
#  'hor',
#  'feet',
#  'beat',
#  'excit',
#  'rhythm',
#  'red',
#  'coat',
#  'fox',
#  'hunter',
#  'urg',
#  'chase',
#  'hill',
#  'meadow',
#  'ran',
#  'sli',
#  'fox',
#  'run',
#  'life',
#  'dog',
#  'get',
#  'closer',
#  'closer',
#  'jump',
#  'across',
#  'brook',
#  'spi',
#  'hole',
#  'among',
#  'bush',
#  'slid',
#  'dog',
#  'went',
#  'side',
#  'stream',
#  'water',
#  'jump',
#  'across',
#  'lost',
#  'scent',
#  'sli',
#  'fox',
#  'quickli',
#  'ran',
#  'hole',
#  'took',
#  'opposit',
#  'direct',
#  'way',
#  'dog',
#  'go',
#  'frighten',
#  'near',
#  'death',
#  'resolv',
#  'never',
#  'bother',
#  'rabbit',
#  'famili',
#  'meanwhil',
#  'papa',
#  'rabbit',
#  'heard',
#  'hound',
#  'start',
#  'chase',
#  'turn',
#  'mama',
#  'rabbit',
#  'cri',
#  'safe',
#  'last',
#  'call',
#  'littl',
#  'rab',
#  'prayer',
#  'thanksgiv',
#  'prai',
#  'father',
#  'art',
#  'heaven',
#  'prayer',
#  'mama',
#  'rabbit',
#  'hustl',
#  'make',
#  'mint',
#  'tea',
#  'papa',
#  'rabbit',
#  'hot',
#  'chocol',
#  'pile',
#  'high',
#  'whip',
#  'cream',
#  'littl',
#  'rab',
#  'time',
#  'live',
#  'happili',
#  'among',
#  'great',
#  'whisper',
#  'pine',
#  'never',
#  'bother',
#  'old',
#  'sli',
#  'fox',
#  'beulah',
#  'murrel']

# %% [markdown]
# ## 5) List top 10 words with highest TF-IDF Values

# %%
tf_idf_result_temp = tf_idf_result
tf_idf_result_temp_sorted = sorted(tf_idf_result_temp.items(), key = lambda kv:(kv[0], kv[1]))
tf_idf_result_temp_sorted
# Out:
# [((0, 'across'), 0.0015872211370430301),
#  ((1, 'languid'), 0.000904106223990672),
#  ((1, 'lap'), 0.000452053111995336),
#  ((1, 'last'), 0.0007232849791925376),
#  ((1, 'late'), 0.0003874740959960023),
#  ((1, 'later'), 0.00020091249422014935),
#  ((1, 'latter'), 0.00030136874133022403),
#  ((1, 'laughter'), 0.00030136874133022403),
#  ((1, 'law'), 0.0006780796679930041),
#  ((1, 'lawyer'), 0.0015068437066511203),
#  ((1, 'lay'), 0.00015068437066511202),
#  ((1, 'lead'), 0.0001808212447981344),
#  ((1, 'leaden'), 0.000452053111995336),
#  ((1, 'leader'), 0.000226026555997668),
#  ((1, 'lean'), 0.000226026555997668),
#  ((1, 'learn'), 0.00015068437066511202),
#  ((1, 'least'), 0.00015068437066511202),
#  ((1, 'leav'), 0.000301368741330224),
#  ((1, 'left'), 9.04106223990672e-05),
#  ((1, 'legal'), 0.000452053111995336),
#  ((1, 'less'), 0.0007534218533255602),
#  ((1, 'lesson'), 0.000452053111995336),
#  ((1, 'let'), 0.0003616424895962688),
#  ((1, 'letter'), 0.0003616424895962688),
#  ((1, 'liber'), 0.000452053111995336),
#  ((1, 'lie'), 0.0002583160639973349),
#  ((1, 'life'), 0.0007910929459918381),
#  ((1, 'light'), 0.000301368741330224),
#  ((1, 'like'), 0.0007534218533255602),
#  ((1, 'line'), 0.00015068437066511202),
#  ((1, 'link'), 0.0001808212447981344),
#  ((1, 'lip'), 0.00015068437066511202),
#  ((1, 'listen'), 0.00033903983399650203),
#  ((1, 'litter'), 0.00030136874133022403),
#  ((1, 'littl'), 0.0006575317992659433),
#  ((1, 'live'), 0.0003767109266627801),
#  ...]

# %%
tf_idf_result_temp_sorted[0]
# Out:
# ((0, 'across'), 0.0015872211370430301)

# %%
tf_idf_result_temp_sorted[0][0]
# Out:
# (0, 'across')

# %%
tf_idf_result_temp_sorted[0][0][0]
# Out:
# 0

# %%
tf_idf_result_temp_abovezero = {}
counter = 0

for i in tf_idf_result_temp_sorted:
    num, decimal = [str(part) for part in str(i[1]).split('.')]
    key = tf_idf_result_temp_sorted[counter][0]
    val = tf_idf_result_temp_sorted[counter][1]
    
    if (int(num) > 1):
        tf_idf_result_temp_abovezero[key] = val
        #print(key)
        #print(val)
        #print(i[1])
    counter +=1
            
tf_idf_result_temp_abovezero = sorted(dict(tf_idf_result_temp_abovezero).items(), key = lambda kv:(kv[1], kv[0]))

# %%
print(len(tf_idf_result_temp_abovezero))
tf_idf_result_temp_abovezero
# Out:
# 167
# [((9, 'began'), 5.904715480240191e-05),
#  ((9, 'set'), 5.904715480240191e-05),
#  ((9, 'poor'), 6.49518702826421e-05),
#  ((9, 'ran'), 6.49518702826421e-05),
#  ((9, 'tri'), 6.49518702826421e-05),
#  ((9, 'wind'), 6.49518702826421e-05),
#  ((7, 'began'), 6.880413523596494e-05),
#  ((11, 'face'), 6.966185109890104e-05),
#  ((11, 'part'), 6.966185109890104e-05),
#  ((4, 'head'), 7.061307558257726e-05),
#  ((4, 'live'), 7.061307558257726e-05),
#  ((9, 'becam'), 7.216874475849121e-05),
#  ((7, 'wont'), 9.460568594945177e-05),
#  ((11, 'alreadi'), 9.951693014128721e-05),
#  ((11, 'cant'), 9.951693014128721e-05),
#  ((11, 'cour'), 9.951693014128721e-05),
#  ((11, 'drew'), 9.951693014128721e-05),
#  ((11, 'easili'), 9.951693014128721e-05),
#  ((11, 'enough'), 9.951693014128721e-05),
#  ((11, 'enter'), 9.951693014128721e-05),
#  ((11, 'four'), 9.951693014128721e-05),
#  ((11, 'furiou'), 9.951693014128721e-05),
#  ((11, 'hair'), 9.951693014128721e-05),
#  ((11, 'half'), 9.951693014128721e-05),
#  ((11, 'hour'), 9.951693014128721e-05),
#  ((11, 'hundr'), 9.951693014128721e-05),
#  ((11, 'lock'), 9.951693014128721e-05),
#  ((11, 'matter'), 9.951693014128721e-05),
#  ((11, 'pay'), 9.951693014128721e-05),
#  ((11, 'pocket'), 9.951693014128721e-05),
#  ((11, 'rain'), 9.951693014128721e-05),
#  ((11, 'real'), 9.951693014128721e-05),
#  ((11, 'receiv'), 9.951693014128721e-05),
#  ((11, 'red'), 9.951693014128721e-05),
#  ((11, 'sent'), 9.951693014128721e-05),
#  ((11, 'sever'), 9.951693014128721e-05),
#  ((11, 'shake'), 9.951693014128721e-05),
#  ((11, 'shape'), 9.951693014128721e-05),
#  ((11, 'sharp'), 9.951693014128721e-05),
#  ((11, 'someon'), 9.951693014128721e-05),
#  ((11, 'troubl'), 9.951693014128721e-05),
#  ((11, 'understand'), 9.951693014128721e-05),
#  ((11, 'warn'), 9.951693014128721e-05),
#  ((11, 'woman'), 9.951693014128721e-05)]

# %% [markdown]
# #### The 10 words with highest TF-IDF Values
#
# ##### Note that the words and their weightage appear in descend order below.

# %%
i = len(tf_idf_result_temp_abovezero) - 10
for item in tf_idf_result_temp_abovezero:
    print(tf_idf_result_temp_abovezero[i])
    i +=1
    if(i == len(tf_idf_result_temp_abovezero)):
        break
# Out:
# ((11, 'sent'), 9.951693014128721e-05)
# ((11, 'sever'), 9.951693014128721e-05)
# ((11, 'shake'), 9.951693014128721e-05)
# ((11, 'shape'), 9.951693014128721e-05)
# ((11, 'sharp'), 9.951693014128721e-05)
# ((11, 'someon'), 9.951693014128721e-05)
# ((11, 'troubl'), 9.951693014128721e-05)
# ((11, 'understand'), 9.951693014128721e-05)
# ((11, 'warn'), 9.951693014128721e-05)
# ((11, 'woman'), 9.951693014128721e-05)

# %% [markdown]
# #### However the Unigrams with highest weightage based on the number of times used are...

# %%
# Unigrams
(pd.Series(nltk.ngrams(words_merged, 1)).value_counts())[:10]
# Out:
# (one,)      212
# (holm,)     196
# (said,)     192
# (man,)      139
# (mr,)       138
# (well,)     136
# (would,)    124
# (upon,)     115
# (could,)    109
# (come,)     107
# dtype: int64

# %% [markdown]
# ## Perform Part of Speech Tagging

# %% [markdown]
# ### 6) Label the TF-IDF Dataset

# %%
# To use tf_idf_result or words_merged to process the dataset for the tagging.

# Downloading and importing the brown corpus
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\niranjans3ln\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
