# %%
# Import Module
import os

# Folder Path
cwd = os.getcwd()
print("Current Working Directory: ", cwd)
path = ''
path = os.getcwd() + '\stories'
print("PATH: ", path)

# Change the directory
os.chdir(path)

# Read text File and Print
def print_text_file_content(file_path):
    with open(file_path, 'r') as f:
        print(f.read())
        
# Read text File and Return
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        return f.read()

# Array of Stories
stories = []
counter = 0

# iterate through all files
for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = f"{path}\{file}"
        print('File: ', file_path)

        # Print Text File Content
        # print_text_file_content(file_path)
        
        # Get Text File Content to Array
        stories.insert(counter, read_text_file(file_path))
        counter +=1
        
print('Counter: ', counter)
for story in stories:
    print('@@@@@@@@@@@@@@@@@@@@@@ Story @@@@@@@@@@@@@@@@@@@@')
    print(story)
# Out:
# Current Working Directory:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining
# PATH:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\13chil.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\3gables.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\3lpigs.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\3student.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\3wishes.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\4moons.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\5orange.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\6ablemen.txt
# File:  C:\Users\niranjans3ln\01 BITS Pilani\Assignments\Text Mining\stories\6napolen.txt
# ...
